# %%
from openbb import obb
obb.user.preferences.output_type = "dataframe"

# %%
chains = obb.derivatives.options.chains(symbol="SPY")

# %%
chains.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8295 entries, 0 to 8294
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   underlying_symbol   8295 non-null   object
#  1   underlying_price    8295 non-null   float64
#  2   contract_symbol     8295 non-null   object
#  3   expiration          8295 non-null   object
#  4   dte                 8295 non-null   int64
#  5   strike              8295 non-null   float64
#  6   option_type         8295 non-null   object
#  7   open_interest       8295 non-null   int64
#  8   volume              8295 non-null   int64
#  9   last_trade_price    8295 non-null   float64
#  10  last_trade_time     8295 non-null   datetime64[ns, America/New_York]
#  11  bid                 8295 non-null   float64
#  12  ask                 8295 non-null   float64
#  13  change              8295 non-null   float64
#  14  change_percent      7169 non-null   float64
#  15  implied_volatility  8295 non-null   float64
#  16  in_the_money        8295 non-null   bool
#  17  currency            8295 non-null   object
# dtypes: bool(1), datetime64[ns, America/New_York](1), float64(8), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
data = obb.equity.price.historical(
    symbol="SPY241220C00550000",
    provider="yfinance",
)[["close", "volume"]]
print(data)
# Out:
#                 close  volume
# date
# 2023-11-10   1.920000       3
# 2023-11-13   1.940000      13
# 2023-11-14   2.660000     159
# 2023-11-15   2.800000      44
# 2023-11-16   2.660000      33
# ...               ...     ...
# 2024-11-04  29.850000      51
# 2024-11-05  34.330002     249
# 2024-11-06  47.450001     123
# 2024-11-07  51.389999      81
# 2024-11-08  53.090000     483
#
# [249 rows x 2 columns]
